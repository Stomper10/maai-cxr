# %%
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import shap
#import shap.explainers.deep.deep_tf
import lime
from lime.lime_image import LimeImageExplainer
from PIL import Image
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import keras.backend as K
from keras.models import Sequential
import ssl
from skimage.segmentation import mark_boundaries

import argparse
import numpy as np
import pandas as pd
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image


from modules.model import A2IModel
# from modules.model_ensemble import Expert as A2IModel
from modules.lr_scheduler import CustomOneCycleSchedule, LearningRateLogger
import functions
from cfg import configs
# from cfg_label_ensemble import configs


data_path = '/home/gyuseonglee/workspace/dataset/chexpert-resized'
# data_path = YOUR_DATA_DIR
full_model_weight_path = '/home/gyuseonglee/workspace/maai-cxr/src/kslee001/quantization/weights/ensemble/densenet121_7000_test.h5'
# quant_model_wieght_path = '/home/gyuseonglee/workspace/maai-cxr/src/kslee001/ensemble/densenet121_1005.tflite'
# path = YOUR_MODEL_PATH

if __name__ == '__main__':
    configs.model.backbone = 'densenet'
    configs.wandb.use_wandb = False
    configs.general.batch_size = 1
    
    # ===== CHECK YOUR DATA DIRECTORY ===== 
    configs.dataset.data_dir = data_path
    # ===== CHECK YOUR DATA DIRECTORY ===== 
    
    configs.dataset.cutoff = 1000


    train_dataset, valid_dataset, test_dataset = functions.load_datasets(configs) 
    configs.general.steps_per_epoch = train_dataset.steps_per_epoch
    
    
    """
    LOAD FULL MODEL (TF)
    """
    model = A2IModel(configs=configs)
    model.initialize()
    
    # ===== CHECK YOUR FULL MODEL WEIGHT DIRECTORY ===== 
    model.load_weights(full_model_weight_path)
    # ===== CHECK YOUR FULL MODEL WEIGHT DIRECTORY ===== 

    
    criterion = tf.keras.losses.CategoricalCrossentropy(
        # from_logits=True,
        from_logits=False, 
        label_smoothing=configs.model.label_smoothing,
        reduction=tf.keras.losses.Reduction.SUM if configs.general.distributed else 'auto'
    )
    model.compile(loss=criterion)

# %%
model.summary()
# Out:
# Model: "a2i_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet_augmentation_rando  (None, 320, 320, 1)      0
#  m_rotation (RandomRotation)
#
#  densenet_augmentation_rando  (None, 320, 320, 1)      0
#  m_translation (RandomZoom)
#
#  densenet_stem_zeropad1 (Zer  (None, 326, 326, 1)      0
#  oPadding2D)
#
#  densenet_stem_conv (Conv2D)  (None, 160, 160, 64)     3136
#
#  densenet_stem_bn (BatchNorm  (None, 160, 160, 64)     256
#  alization)
#
#  densenet_stem_act (Activati  (None, 160, 160, 64)     0
#  on)
#
#  densenet_stem_zeropad2 (Zer  (None, 162, 162, 64)     0
#  oPadding2D)
#
#  densenet_stem_maxpool (MaxP  (None, 80, 80, 64)       0
#  ooling2D)
#
#  densenet_denseblock_0_0_bn1  (None, 80, 80, 64)       256
#   (BatchNormalization)
#
#  densenet_denseblock_0_0_act  (None, 80, 80, 64)       0
#  1 (Activation)
#
#  densenet_denseblock_0_0_con  (None, 80, 80, 128)      8192
#  v1 (Conv2D)
#
#  densenet_denseblock_0_0_bn2  (None, 80, 80, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_0_0_act  (None, 80, 80, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_0_0_con  (None, 80, 80, 32)       36864
#  v2 (Conv2D)
#
#  densenet_denseblock_0_0_con  (None, 80, 80, 96)       0
#  catenate (Concatenate)
#
#  densenet_denseblock_0_1_bn1  (None, 80, 80, 96)       384
#   (BatchNormalization)
#
#  densenet_denseblock_0_1_act  (None, 80, 80, 96)       0
#  1 (Activation)
#
#  densenet_denseblock_0_1_con  (None, 80, 80, 128)      12288
#  v1 (Conv2D)
#
#  densenet_denseblock_0_1_bn2  (None, 80, 80, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_0_1_act  (None, 80, 80, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_0_1_con  (None, 80, 80, 32)       36864
#  v2 (Conv2D)
#
#  densenet_denseblock_0_1_con  (None, 80, 80, 128)      0
#  catenate (Concatenate)
#
#  densenet_denseblock_0_2_bn1  (None, 80, 80, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_0_2_act  (None, 80, 80, 128)      0
#  1 (Activation)
#
#  densenet_denseblock_0_2_con  (None, 80, 80, 128)      16384
#  v1 (Conv2D)
#
#  densenet_denseblock_0_2_bn2  (None, 80, 80, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_0_2_act  (None, 80, 80, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_0_2_con  (None, 80, 80, 32)       36864
#  v2 (Conv2D)
#
#  densenet_denseblock_0_2_con  (None, 80, 80, 160)      0
#  catenate (Concatenate)
#
#  densenet_denseblock_0_3_bn1  (None, 80, 80, 160)      640
#   (BatchNormalization)
#
#  densenet_denseblock_0_3_act  (None, 80, 80, 160)      0
#  1 (Activation)
#
#  densenet_denseblock_0_3_con  (None, 80, 80, 128)      20480
#  v1 (Conv2D)
#
#  densenet_denseblock_0_3_bn2  (None, 80, 80, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_0_3_act  (None, 80, 80, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_0_3_con  (None, 80, 80, 32)       36864
#  v2 (Conv2D)
#
#  densenet_denseblock_0_3_con  (None, 80, 80, 192)      0
#  catenate (Concatenate)
#
#  densenet_denseblock_0_4_bn1  (None, 80, 80, 192)      768
#   (BatchNormalization)
#
#  densenet_denseblock_0_4_act  (None, 80, 80, 192)      0
#  1 (Activation)
#
#  densenet_denseblock_0_4_con  (None, 80, 80, 128)      24576
#  v1 (Conv2D)
#
#  densenet_denseblock_0_4_bn2  (None, 80, 80, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_0_4_act  (None, 80, 80, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_0_4_con  (None, 80, 80, 32)       36864
#  v2 (Conv2D)
#
#  densenet_denseblock_0_4_con  (None, 80, 80, 224)      0
#  catenate (Concatenate)
#
#  densenet_denseblock_0_5_bn1  (None, 80, 80, 224)      896
#   (BatchNormalization)
#
#  densenet_denseblock_0_5_act  (None, 80, 80, 224)      0
#  1 (Activation)
#
#  densenet_denseblock_0_5_con  (None, 80, 80, 128)      28672
#  v1 (Conv2D)
#
#  densenet_denseblock_0_5_bn2  (None, 80, 80, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_0_5_act  (None, 80, 80, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_0_5_con  (None, 80, 80, 32)       36864
#  v2 (Conv2D)
#
#  densenet_denseblock_0_5_con  (None, 80, 80, 256)      0
#  catenate (Concatenate)
#
#  densenet_transition_0_bn (B  (None, 80, 80, 256)      1024
#  atchNormalization)
#
#  densenet_transition_0_act (  (None, 80, 80, 256)      0
#  Activation)
#
#  densenet_transition_0_conv   (None, 80, 80, 128)      32768
#  (Conv2D)
#
#  densenet_transition_0_pool   (None, 40, 40, 128)      0
#  (AveragePooling2D)
#
#  densenet_denseblock_1_0_bn1  (None, 40, 40, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_1_0_act  (None, 40, 40, 128)      0
#  1 (Activation)
#
#  densenet_denseblock_1_0_con  (None, 40, 40, 128)      16384
#  v1 (Conv2D)
#
#  densenet_denseblock_1_0_bn2  (None, 40, 40, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_1_0_act  (None, 40, 40, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_1_0_con  (None, 40, 40, 32)       36864
#  v2 (Conv2D)
#
#  densenet_denseblock_1_0_con  (None, 40, 40, 160)      0
#  catenate (Concatenate)
#
#  densenet_denseblock_1_1_bn1  (None, 40, 40, 160)      640
#   (BatchNormalization)
#
#  densenet_denseblock_1_1_act  (None, 40, 40, 160)      0
#  1 (Activation)
#
#  densenet_denseblock_1_1_con  (None, 40, 40, 128)      20480
#  v1 (Conv2D)
#
#  densenet_denseblock_1_1_bn2  (None, 40, 40, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_1_1_act  (None, 40, 40, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_1_1_con  (None, 40, 40, 32)       36864
#  v2 (Conv2D)
#
#  densenet_denseblock_1_1_con  (None, 40, 40, 192)      0
#  catenate (Concatenate)
#
#  densenet_denseblock_1_2_bn1  (None, 40, 40, 192)      768
#   (BatchNormalization)
#
#  densenet_denseblock_1_2_act  (None, 40, 40, 192)      0
#  1 (Activation)
#
#  densenet_denseblock_1_2_con  (None, 40, 40, 128)      24576
#  v1 (Conv2D)
#
#  densenet_denseblock_1_2_bn2  (None, 40, 40, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_1_2_act  (None, 40, 40, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_1_2_con  (None, 40, 40, 32)       36864
#  v2 (Conv2D)
#
#  densenet_denseblock_1_2_con  (None, 40, 40, 224)      0
#  catenate (Concatenate)
#
#  densenet_denseblock_1_3_bn1  (None, 40, 40, 224)      896
#   (BatchNormalization)
#
#  densenet_denseblock_1_3_act  (None, 40, 40, 224)      0
#  1 (Activation)
#
#  densenet_denseblock_1_3_con  (None, 40, 40, 128)      28672
#  v1 (Conv2D)
#
#  densenet_denseblock_1_3_bn2  (None, 40, 40, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_1_3_act  (None, 40, 40, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_1_3_con  (None, 40, 40, 32)       36864
#  v2 (Conv2D)
#
#  densenet_denseblock_1_3_con  (None, 40, 40, 256)      0
#  catenate (Concatenate)
#
#  densenet_denseblock_1_4_bn1  (None, 40, 40, 256)      1024
#   (BatchNormalization)
#
#  densenet_denseblock_1_4_act  (None, 40, 40, 256)      0
#  1 (Activation)
#
#  densenet_denseblock_1_4_con  (None, 40, 40, 128)      32768
#  v1 (Conv2D)
#
#  densenet_denseblock_1_4_bn2  (None, 40, 40, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_1_4_act  (None, 40, 40, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_1_4_con  (None, 40, 40, 32)       36864
#  v2 (Conv2D)
#
#  densenet_denseblock_1_4_con  (None, 40, 40, 288)      0
#  catenate (Concatenate)
#
#  densenet_denseblock_1_5_bn1  (None, 40, 40, 288)      1152
#   (BatchNormalization)
#
#  densenet_denseblock_1_5_act  (None, 40, 40, 288)      0
#  1 (Activation)
#
#  densenet_denseblock_1_5_con  (None, 40, 40, 128)      36864
#  v1 (Conv2D)
#
#  densenet_denseblock_1_5_bn2  (None, 40, 40, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_1_5_act  (None, 40, 40, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_1_5_con  (None, 40, 40, 32)       36864
#  v2 (Conv2D)
#
#  densenet_denseblock_1_5_con  (None, 40, 40, 320)      0
#  catenate (Concatenate)
#
#  densenet_denseblock_1_6_bn1  (None, 40, 40, 320)      1280
#   (BatchNormalization)
#
#  densenet_denseblock_1_6_act  (None, 40, 40, 320)      0
#  1 (Activation)
#
#  densenet_denseblock_1_6_con  (None, 40, 40, 128)      40960
#  v1 (Conv2D)
#
#  densenet_denseblock_1_6_bn2  (None, 40, 40, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_1_6_act  (None, 40, 40, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_1_6_con  (None, 40, 40, 32)       36864
#  v2 (Conv2D)
#
#  densenet_denseblock_1_6_con  (None, 40, 40, 352)      0
#  catenate (Concatenate)
#
#  densenet_denseblock_1_7_bn1  (None, 40, 40, 352)      1408
#   (BatchNormalization)
#
#  densenet_denseblock_1_7_act  (None, 40, 40, 352)      0
#  1 (Activation)
#
#  densenet_denseblock_1_7_con  (None, 40, 40, 128)      45056
#  v1 (Conv2D)
#
#  densenet_denseblock_1_7_bn2  (None, 40, 40, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_1_7_act  (None, 40, 40, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_1_7_con  (None, 40, 40, 32)       36864
#  v2 (Conv2D)
#
#  densenet_denseblock_1_7_con  (None, 40, 40, 384)      0
#  catenate (Concatenate)
#
#  densenet_denseblock_1_8_bn1  (None, 40, 40, 384)      1536
#   (BatchNormalization)
#
#  densenet_denseblock_1_8_act  (None, 40, 40, 384)      0
#  1 (Activation)
#
#  densenet_denseblock_1_8_con  (None, 40, 40, 128)      49152
#  v1 (Conv2D)
#
#  densenet_denseblock_1_8_bn2  (None, 40, 40, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_1_8_act  (None, 40, 40, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_1_8_con  (None, 40, 40, 32)       36864
#  v2 (Conv2D)
#
#  densenet_denseblock_1_8_con  (None, 40, 40, 416)      0
#  catenate (Concatenate)
#
#  densenet_denseblock_1_9_bn1  (None, 40, 40, 416)      1664
#   (BatchNormalization)
#
#  densenet_denseblock_1_9_act  (None, 40, 40, 416)      0
#  1 (Activation)
#
#  densenet_denseblock_1_9_con  (None, 40, 40, 128)      53248
#  v1 (Conv2D)
#
#  densenet_denseblock_1_9_bn2  (None, 40, 40, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_1_9_act  (None, 40, 40, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_1_9_con  (None, 40, 40, 32)       36864
#  v2 (Conv2D)
#
#  densenet_denseblock_1_9_con  (None, 40, 40, 448)      0
#  catenate (Concatenate)
#  densenet_denseblock_1_10_bn  (None, 40, 40, 448)      1792
#  1 (BatchNormalization)
#
#  densenet_denseblock_1_10_ac  (None, 40, 40, 448)      0
#  t1 (Activation)
#
#  densenet_denseblock_1_10_co  (None, 40, 40, 128)      57344
#  nv1 (Conv2D)
#
#  densenet_denseblock_1_10_bn  (None, 40, 40, 128)      512
#  2 (BatchNormalization)
#
#  densenet_denseblock_1_10_ac  (None, 40, 40, 128)      0
#  t2 (Activation)
#
#  densenet_denseblock_1_10_co  (None, 40, 40, 32)       36864
#  nv2 (Conv2D)
#
#  densenet_denseblock_1_10_co  (None, 40, 40, 480)      0
#  ncatenate (Concatenate)
#
#  densenet_denseblock_1_11_bn  (None, 40, 40, 480)      1920
#  1 (BatchNormalization)
#
#  densenet_denseblock_1_11_ac  (None, 40, 40, 480)      0
#  t1 (Activation)
#
#  densenet_denseblock_1_11_co  (None, 40, 40, 128)      61440
#  nv1 (Conv2D)
#
#  densenet_denseblock_1_11_bn  (None, 40, 40, 128)      512
#  2 (BatchNormalization)
#
#  densenet_denseblock_1_11_ac  (None, 40, 40, 128)      0
#  t2 (Activation)
#
#  densenet_denseblock_1_11_co  (None, 40, 40, 32)       36864
#  nv2 (Conv2D)
#
#  densenet_denseblock_1_11_co  (None, 40, 40, 512)      0
#  ncatenate (Concatenate)
#
#  densenet_transition_1_bn (B  (None, 40, 40, 512)      2048
#  atchNormalization)
#
#  densenet_transition_1_act (  (None, 40, 40, 512)      0
#  Activation)
#
#  densenet_transition_1_conv   (None, 40, 40, 256)      131072
#  (Conv2D)
#
#  densenet_transition_1_pool   (None, 20, 20, 256)      0
#  (AveragePooling2D)
#
#  densenet_denseblock_2_0_bn1  (None, 20, 20, 256)      1024
#   (BatchNormalization)
#
#  densenet_denseblock_2_0_act  (None, 20, 20, 256)      0
#  1 (Activation)
#
#  densenet_denseblock_2_0_con  (None, 20, 20, 128)      32768
#  v1 (Conv2D)
#
#  densenet_denseblock_2_0_bn2  (None, 20, 20, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_2_0_act  (None, 20, 20, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_2_0_con  (None, 20, 20, 32)       36864
#  v2 (Conv2D)
#
#  densenet_denseblock_2_0_con  (None, 20, 20, 288)      0
#  catenate (Concatenate)
#
#  densenet_denseblock_2_1_bn1  (None, 20, 20, 288)      1152
#   (BatchNormalization)
#
#  densenet_denseblock_2_1_act  (None, 20, 20, 288)      0
#  1 (Activation)
#
#  densenet_denseblock_2_1_con  (None, 20, 20, 128)      36864
#  v1 (Conv2D)
#
#  densenet_denseblock_2_1_bn2  (None, 20, 20, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_2_1_act  (None, 20, 20, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_2_1_con  (None, 20, 20, 32)       36864
#  v2 (Conv2D)
#
#  densenet_denseblock_2_1_con  (None, 20, 20, 320)      0
#  catenate (Concatenate)
#
#  densenet_denseblock_2_2_bn1  (None, 20, 20, 320)      1280
#   (BatchNormalization)
#
#  densenet_denseblock_2_2_act  (None, 20, 20, 320)      0
#  1 (Activation)
#
#  densenet_denseblock_2_2_con  (None, 20, 20, 128)      40960
#  v1 (Conv2D)
#
#  densenet_denseblock_2_2_bn2  (None, 20, 20, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_2_2_act  (None, 20, 20, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_2_2_con  (None, 20, 20, 32)       36864
#  v2 (Conv2D)
#
#  densenet_denseblock_2_2_con  (None, 20, 20, 352)      0
#  catenate (Concatenate)
#
#  densenet_denseblock_2_3_bn1  (None, 20, 20, 352)      1408
#   (BatchNormalization)
#
#  densenet_denseblock_2_3_act  (None, 20, 20, 352)      0
#  1 (Activation)
#
#  densenet_denseblock_2_3_con  (None, 20, 20, 128)      45056
#  v1 (Conv2D)
#
#  densenet_denseblock_2_3_bn2  (None, 20, 20, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_2_3_act  (None, 20, 20, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_2_3_con  (None, 20, 20, 32)       36864
#  v2 (Conv2D)
#
#  densenet_denseblock_2_3_con  (None, 20, 20, 384)      0
#  catenate (Concatenate)
#
#  densenet_denseblock_2_4_bn1  (None, 20, 20, 384)      1536
#   (BatchNormalization)
#
#  densenet_denseblock_2_4_act  (None, 20, 20, 384)      0
#  1 (Activation)
#
#  densenet_denseblock_2_4_con  (None, 20, 20, 128)      49152
#  v1 (Conv2D)
#
#  densenet_denseblock_2_4_bn2  (None, 20, 20, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_2_4_act  (None, 20, 20, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_2_4_con  (None, 20, 20, 32)       36864
#  v2 (Conv2D)
#
#  densenet_denseblock_2_4_con  (None, 20, 20, 416)      0
#  catenate (Concatenate)
#
#  densenet_denseblock_2_5_bn1  (None, 20, 20, 416)      1664
#   (BatchNormalization)
#
#  densenet_denseblock_2_5_act  (None, 20, 20, 416)      0
#  1 (Activation)
#
#  densenet_denseblock_2_5_con  (None, 20, 20, 128)      53248
#  v1 (Conv2D)
#
#  densenet_denseblock_2_5_bn2  (None, 20, 20, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_2_5_act  (None, 20, 20, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_2_5_con  (None, 20, 20, 32)       36864
#  v2 (Conv2D)
#
#  densenet_denseblock_2_5_con  (None, 20, 20, 448)      0
#  catenate (Concatenate)
#
#  densenet_denseblock_2_6_bn1  (None, 20, 20, 448)      1792
#   (BatchNormalization)
#
#  densenet_denseblock_2_6_act  (None, 20, 20, 448)      0
#  1 (Activation)
#
#  densenet_denseblock_2_6_con  (None, 20, 20, 128)      57344
#  v1 (Conv2D)
#
#  densenet_denseblock_2_6_bn2  (None, 20, 20, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_2_6_act  (None, 20, 20, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_2_6_con  (None, 20, 20, 32)       36864
#  v2 (Conv2D)
#
#  densenet_denseblock_2_6_con  (None, 20, 20, 480)      0
#  catenate (Concatenate)
#
#  densenet_denseblock_2_7_bn1  (None, 20, 20, 480)      1920
#   (BatchNormalization)
#
#  densenet_denseblock_2_7_act  (None, 20, 20, 480)      0
#  1 (Activation)
#
#  densenet_denseblock_2_7_con  (None, 20, 20, 128)      61440
#  v1 (Conv2D)
#
#  densenet_denseblock_2_7_bn2  (None, 20, 20, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_2_7_act  (None, 20, 20, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_2_7_con  (None, 20, 20, 32)       36864
#  v2 (Conv2D)
#
#  densenet_denseblock_2_7_con  (None, 20, 20, 512)      0
#  catenate (Concatenate)
#
#  densenet_denseblock_2_8_bn1  (None, 20, 20, 512)      2048
#   (BatchNormalization)
#
#  densenet_denseblock_2_8_act  (None, 20, 20, 512)      0
#  1 (Activation)
#
#  densenet_denseblock_2_8_con  (None, 20, 20, 128)      65536
#  v1 (Conv2D)
#
#  densenet_denseblock_2_8_bn2  (None, 20, 20, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_2_8_act  (None, 20, 20, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_2_8_con  (None, 20, 20, 32)       36864
#  v2 (Conv2D)
#
#  densenet_denseblock_2_8_con  (None, 20, 20, 544)      0
#  catenate (Concatenate)
#
#  densenet_denseblock_2_9_bn1  (None, 20, 20, 544)      2176
#   (BatchNormalization)
#
#  densenet_denseblock_2_9_act  (None, 20, 20, 544)      0
#  1 (Activation)
#
#  densenet_denseblock_2_9_con  (None, 20, 20, 128)      69632
#  v1 (Conv2D)
#
#  densenet_denseblock_2_9_bn2  (None, 20, 20, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_2_9_act  (None, 20, 20, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_2_9_con  (None, 20, 20, 32)       36864
#  v2 (Conv2D)
#
#  densenet_denseblock_2_9_con  (None, 20, 20, 576)      0
#  catenate (Concatenate)
#
#  densenet_denseblock_2_10_bn  (None, 20, 20, 576)      2304
#  1 (BatchNormalization)
#
#  densenet_denseblock_2_10_ac  (None, 20, 20, 576)      0
#  t1 (Activation)
#
#  densenet_denseblock_2_10_co  (None, 20, 20, 128)      73728
#  nv1 (Conv2D)
#
#  densenet_denseblock_2_10_bn  (None, 20, 20, 128)      512
#  2 (BatchNormalization)
#
#  densenet_denseblock_2_10_ac  (None, 20, 20, 128)      0
#  t2 (Activation)
#
#  densenet_denseblock_2_10_co  (None, 20, 20, 32)       36864
#  nv2 (Conv2D)
#
#  densenet_denseblock_2_10_co  (None, 20, 20, 608)      0
#  ncatenate (Concatenate)
#
#  densenet_denseblock_2_11_bn  (None, 20, 20, 608)      2432
#  1 (BatchNormalization)
#
#  densenet_denseblock_2_11_ac  (None, 20, 20, 608)      0
#  t1 (Activation)
#
#  densenet_denseblock_2_11_co  (None, 20, 20, 128)      77824
#  nv1 (Conv2D)
#
#  densenet_denseblock_2_11_bn  (None, 20, 20, 128)      512
#  2 (BatchNormalization)
#
#  densenet_denseblock_2_11_ac  (None, 20, 20, 128)      0
#  t2 (Activation)
#
#  densenet_denseblock_2_11_co  (None, 20, 20, 32)       36864
#  nv2 (Conv2D)
#
#  densenet_denseblock_2_11_co  (None, 20, 20, 640)      0
#  ncatenate (Concatenate)
#
#  densenet_denseblock_2_12_bn  (None, 20, 20, 640)      2560
#  1 (BatchNormalization)
#
#  densenet_denseblock_2_12_ac  (None, 20, 20, 640)      0
#  t1 (Activation)
#
#  densenet_denseblock_2_12_co  (None, 20, 20, 128)      81920
#  nv1 (Conv2D)
#
#  densenet_denseblock_2_12_bn  (None, 20, 20, 128)      512
#  2 (BatchNormalization)
#
#  densenet_denseblock_2_12_ac  (None, 20, 20, 128)      0
#  t2 (Activation)
#
#  densenet_denseblock_2_12_co  (None, 20, 20, 32)       36864
#  nv2 (Conv2D)
#
#  densenet_denseblock_2_12_co  (None, 20, 20, 672)      0
#  ncatenate (Concatenate)
#
#  densenet_denseblock_2_13_bn  (None, 20, 20, 672)      2688
#  1 (BatchNormalization)
#
#  densenet_denseblock_2_13_ac  (None, 20, 20, 672)      0
#  t1 (Activation)
#
#  densenet_denseblock_2_13_co  (None, 20, 20, 128)      86016
#  nv1 (Conv2D)
#
#  densenet_denseblock_2_13_bn  (None, 20, 20, 128)      512
#  2 (BatchNormalization)
#
#  densenet_denseblock_2_13_ac  (None, 20, 20, 128)      0
#  t2 (Activation)
#
#  densenet_denseblock_2_13_co  (None, 20, 20, 32)       36864
#  nv2 (Conv2D)
#
#  densenet_denseblock_2_13_co  (None, 20, 20, 704)      0
#  ncatenate (Concatenate)
#
#  densenet_denseblock_2_14_bn  (None, 20, 20, 704)      2816
#  1 (BatchNormalization)
#
#  densenet_denseblock_2_14_ac  (None, 20, 20, 704)      0
#  t1 (Activation)
#
#  densenet_denseblock_2_14_co  (None, 20, 20, 128)      90112
#  nv1 (Conv2D)
# ...
#
#  densenet_denseblock_3_4_con  (None, 10, 10, 128)      16384
#  v1 (Conv2D)
#
#  densenet_denseblock_3_4_bn2  (None, 10, 10, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_3_4_act  (None, 10, 10, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_3_4_con  (None, 10, 10, 128)      16384
#  v2 (Conv2D)
#
#  densenet_denseblock_3_5_bn1  (None, 10, 10, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_3_5_act  (None, 10, 10, 128)      0
#  1 (Activation)
#
#  densenet_denseblock_3_5_con  (None, 10, 10, 128)      16384
#  v1 (Conv2D)
#
#  densenet_denseblock_3_5_bn2  (None, 10, 10, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_3_5_act  (None, 10, 10, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_3_5_con  (None, 10, 10, 128)      16384
#  v2 (Conv2D)
#
#  densenet_denseblock_3_6_bn1  (None, 10, 10, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_3_6_act  (None, 10, 10, 128)      0
#  1 (Activation)
#
#  densenet_denseblock_3_6_con  (None, 10, 10, 128)      16384
#  v1 (Conv2D)
#
#  densenet_denseblock_3_6_bn2  (None, 10, 10, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_3_6_act  (None, 10, 10, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_3_6_con  (None, 10, 10, 128)      16384
#  v2 (Conv2D)
#
#  densenet_denseblock_3_7_bn1  (None, 10, 10, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_3_7_act  (None, 10, 10, 128)      0
#  1 (Activation)
#
#  densenet_denseblock_3_7_con  (None, 10, 10, 128)      16384
#  v1 (Conv2D)
#
#  densenet_denseblock_3_7_bn2  (None, 10, 10, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_3_7_act  (None, 10, 10, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_3_7_con  (None, 10, 10, 128)      16384
#  v2 (Conv2D)
#
#  densenet_denseblock_3_8_bn1  (None, 10, 10, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_3_8_act  (None, 10, 10, 128)      0
#  1 (Activation)
#
#  densenet_denseblock_3_8_con  (None, 10, 10, 128)      16384
#  v1 (Conv2D)
#
#  densenet_denseblock_3_8_bn2  (None, 10, 10, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_3_8_act  (None, 10, 10, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_3_8_con  (None, 10, 10, 128)      16384
#  v2 (Conv2D)
#
#  densenet_denseblock_3_9_bn1  (None, 10, 10, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_3_9_act  (None, 10, 10, 128)      0
#  1 (Activation)
#
#  densenet_denseblock_3_9_con  (None, 10, 10, 128)      16384
#  v1 (Conv2D)
#
#  densenet_denseblock_3_9_bn2  (None, 10, 10, 128)      512
#   (BatchNormalization)
#
#  densenet_denseblock_3_9_act  (None, 10, 10, 128)      0
#  2 (Activation)
#
#  densenet_denseblock_3_9_con  (None, 10, 10, 128)      16384
#  v2 (Conv2D)
#  densenet_denseblock_3_10_bn  (None, 10, 10, 128)      512
#  1 (BatchNormalization)
#
#  densenet_denseblock_3_10_ac  (None, 10, 10, 128)      0
#  t1 (Activation)
#
#  densenet_denseblock_3_10_co  (None, 10, 10, 128)      16384
#  nv1 (Conv2D)
#
#  densenet_denseblock_3_10_bn  (None, 10, 10, 128)      512
#  2 (BatchNormalization)
#
#  densenet_denseblock_3_10_ac  (None, 10, 10, 128)      0
#  t2 (Activation)
#
#  densenet_denseblock_3_10_co  (None, 10, 10, 128)      16384
#  nv2 (Conv2D)
#
#  densenet_denseblock_3_11_bn  (None, 10, 10, 128)      512
#  1 (BatchNormalization)
#
#  densenet_denseblock_3_11_ac  (None, 10, 10, 128)      0
#  t1 (Activation)
#
#  densenet_denseblock_3_11_co  (None, 10, 10, 128)      16384
#  nv1 (Conv2D)
#
#  densenet_denseblock_3_11_bn  (None, 10, 10, 128)      512
#  2 (BatchNormalization)
#
#  densenet_denseblock_3_11_ac  (None, 10, 10, 128)      0
#  t2 (Activation)
#
#  densenet_denseblock_3_11_co  (None, 10, 10, 128)      16384
#  nv2 (Conv2D)
#
#  densenet_denseblock_3_12_bn  (None, 10, 10, 128)      512
#  1 (BatchNormalization)
#
#  densenet_denseblock_3_12_ac  (None, 10, 10, 128)      0
#  t1 (Activation)
#
#  densenet_denseblock_3_12_co  (None, 10, 10, 128)      16384
#  nv1 (Conv2D)
#
#  densenet_denseblock_3_12_bn  (None, 10, 10, 128)      512
#  2 (BatchNormalization)
#
#  densenet_denseblock_3_12_ac  (None, 10, 10, 128)      0
#  t2 (Activation)
#
#  densenet_denseblock_3_12_co  (None, 10, 10, 128)      16384
#  nv2 (Conv2D)
#
#  densenet_denseblock_3_13_bn  (None, 10, 10, 128)      512
#  1 (BatchNormalization)
#
#  densenet_denseblock_3_13_ac  (None, 10, 10, 128)      0
#  t1 (Activation)
#
#  densenet_denseblock_3_13_co  (None, 10, 10, 128)      16384
#  nv1 (Conv2D)
#
#  densenet_denseblock_3_13_bn  (None, 10, 10, 128)      512
#  2 (BatchNormalization)
#
#  densenet_denseblock_3_13_ac  (None, 10, 10, 128)      0
#  t2 (Activation)
#
#  densenet_denseblock_3_13_co  (None, 10, 10, 128)      16384
#  nv2 (Conv2D)
#
#  densenet_denseblock_3_14_bn  (None, 10, 10, 128)      512
#  1 (BatchNormalization)
#
#  densenet_denseblock_3_14_ac  (None, 10, 10, 128)      0
#  t1 (Activation)
#
#  densenet_denseblock_3_14_co  (None, 10, 10, 128)      16384
#  nv1 (Conv2D)
#
#  densenet_denseblock_3_14_bn  (None, 10, 10, 128)      512
#  2 (BatchNormalization)
#
#  densenet_denseblock_3_14_ac  (None, 10, 10, 128)      0
#  t2 (Activation)
#
#  densenet_denseblock_3_14_co  (None, 10, 10, 128)      16384
#  nv2 (Conv2D)
#
#  densenet_denseblock_3_15_bn  (None, 10, 10, 128)      512
#  1 (BatchNormalization)
#
#  densenet_denseblock_3_15_ac  (None, 10, 10, 128)      0
#  t1 (Activation)
#
#  densenet_denseblock_3_15_co  (None, 10, 10, 128)      16384
#  nv1 (Conv2D)
#
#  densenet_denseblock_3_15_bn  (None, 10, 10, 128)      512
#  2 (BatchNormalization)
#
#  densenet_denseblock_3_15_ac  (None, 10, 10, 128)      0
#  t2 (Activation)
#
#  densenet_denseblock_3_15_co  (None, 10, 10, 128)      16384
#  nv2 (Conv2D)
#
#  atel_classifier_globalpool   (None, 128)              0
#  (GlobalAveragePooling2D)
#
#  atel_classifier_linear (Den  (None, 2)                258
#  se)
#
#  card_classifier_globalpool   (None, 128)              0
#  (GlobalAveragePooling2D)
#
#  card_classifier_linear (Den  (None, 3)                387
#  se)
#
#  cons_classifier_globalpool   (None, 128)              0
#  (GlobalAveragePooling2D)
#
#  cons_classifier_linear (Den  (None, 2)                258
#  se)
#
#  edem_classifier_globalpool   (None, 128)              0
#  (GlobalAveragePooling2D)
#
#  edem_classifier_linear (Den  (None, 2)                258
#  se)
#
#  plef_classifier_globalpool   (None, 128)              0
#  (GlobalAveragePooling2D)
#
#  plef_classifier_linear (Den  (None, 3)                387
#  se)
#
# =================================================================
# Total params: 5,437,806
# Trainable params: 5,371,404
# Non-trainable params: 66,402
# _________________________________________________________________

# %%
#%%
# load package
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import shap
#import shap.explainers.deep.deep_tf
import lime
from lime import lime_image
from lime.lime_image import LimeImageExplainer
from PIL import Image
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import keras.backend as K
from keras.models import Sequential
import ssl
from skimage.segmentation import mark_boundaries

import argparse
import numpy as np
import pandas as pd
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
from models.ensemble.modules.model import A2IModel
from models.ensemble.modules.lr_scheduler import CustomOneCycleSchedule, LearningRateLogger
import models.ensemble.functions as functions
from models.ensemble.cfg import configs

# %%
import deeplift
from deeplift.layers import NonlinearMxtsMode
from deeplift.conversion import kerasapi_conversion as kc
from deeplift.util import compile_func

# %%
TARGET_COLUMNS = ['Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema', 'Pleural Effusion']
NUM_CLASSES = len(TARGET_COLUMNS)
AUTOTUNE = tf.data.AUTOTUNE
IMAGE_SIZE = [320, 320]
BATCH_SIZE = 1
MODEL_DIR = '/home/n0/a2i006/xai/models/ensemble/test/densenet121_10000_test.h5'
MODEL_DIR_Q = '/home/n0/a2i006/xai/models/baseline_quant_model.tflite'

DATASET_DIR = '/home/n0/a2i006/xai/dataset'
DATASET_NAME = 'CheXpert-v1.0-small'
TEST_SIZE = 0.1 # enough

# %%
# return : dataframe with columns [Path, label_1, label_2, ... label_n]
def csv_to_df(dataset_dir, dataset_name):
    # TODO : load data into pandas dataframe
    data = pd.read_csv(f"{dataset_dir}/valid.csv").fillna(0.0)

    # TODO : fix image path:
    # ex. CheXpert-v1.0/patient0000...
    # ex.       > /mnt/e/dataset/chexpert/CheXpert-v1.0/patient0000...
    data['Path'] = data['Path'].str.replace(dataset_name, dataset_dir, regex=False)

    # TODO : fill null values
    for col_idx in range(5, len(data.columns)):
        data[data.columns[col_idx]] = data[data.columns[col_idx]].astype(str)
        data[data.columns[col_idx]] = data[data.columns[col_idx]].str.replace("-1.0", "0.0").astype(float).fillna(0.0)

    # TODO : column reduction
    target_columns = ['Path'] + TARGET_COLUMNS
    dataframe = data[target_columns].reset_index(drop=True)

    return dataframe

# %%
def process_path_validation(image_path, label):
    # Read the image from the path
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image, channels=1) #3
    image = tf.image.resize(image, [320, 320])
    image = tf.cast(image, tf.float32) / 255.0

    return image, label

# %%
def transform(dataset_dir):
    # make train_images
    train_images = []
    for i in range(64541, 64741):
        img_path = f"{dataset_dir}/valid/patient{i}/study1/view1_frontal.jpg"
        img = image.load_img(img_path, target_size=(320, 320))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = x / 255.0
        train_images.append(x)

    # Convert the list to a numpy array
    # (number_of_images, height, width, channels). (48, 320, 320, 3).
    train_images = np.concatenate(train_images, axis=0) 
    #print(train_images.shape)
    
    return train_images

# %%
def get_model_predictions(data):
    model_prediction = model.predict(data)
    print(f"The predicted class is : {decode_predictions(model_prediction, top=1)[0][0][1]}")
    return decode_predictions(model_prediction, top=1)[0][0][1]

# %%
def generate_prediction_sample(exp, exp_class, weight = 0.1, show_positive = False, hide_background = False):
    '''
    Method to display and highlight super-pixels used by the black-box model to make predictions
    '''
    image, mask = exp.get_image_and_mask(exp_class, 
                                         positive_only=show_positive, 
                                         num_features=6, 
                                         hide_rest=hide_background,
                                         min_weight=weight
                                        )
    plt.imshow(mark_boundaries(image, mask))
    #plt.savefig('lime_pred.png')
    plt.axis('off')
    plt.show()

# %%
def map2layer(x, layer):
    feed_dict = dict(zip([new_model.layers[0].input], [preprocess_input(x.copy())]))
    #feed_dict = dict(zip([interpreter.layers[0].input], [preprocess_input(x.copy())]))
    return K.get_session().run(new_model.layers[layer].input, feed_dict)

# %%
# GPU Setting
physical_devices = tf.config.list_physical_devices('GPU')
print('Num_GPUs:{}, List:{}'.format(len(physical_devices), physical_devices))

# %%
# load df from csv
df = csv_to_df(DATASET_DIR, DATASET_NAME)

# %%
# Filter filenames ending with "_frontal.jpg"
valid_df = df[df['Path'].str.endswith('_frontal.jpg')]
#print(valid_df)

# %%
# Dataset for validation
list_ds_valid = tf.data.Dataset.from_tensor_slices((valid_df['Path'].values, valid_df.iloc[:, 1:].values))
#print(list_ds_valid)
ds_valid = list_ds_valid.map(process_path_validation, num_parallel_calls=AUTOTUNE)
ds_valid = ds_valid.batch(1)
#ds_valid = ds_valid.prefetch(AUTOTUNE)

# %%
sample = next(iter(ds_valid))
sample[0][0].shape

# %% [markdown]
# Full model

# %%
new_model = A2IModel(configs=configs)
new_model.initialize()

# %%
new_model.load_weights(filepath = MODEL_DIR)

# %%
new_model.summary()

# %% [markdown]
# Quantized model

# %%
# load model
#model = load_model(MODEL_DIR, custom_objects={'CosineDecayWithWarmup': CosineDecayWithWarmup, 'AUROC': AUROC})
interpreter = tf.lite.Interpreter(model_path=MODEL_DIR_Q)

# %%
interpreter.get_input_details()

# %%
interpreter.allocate_tensors()

# %%
input_index = interpreter.get_input_details()[0]['index']
input_index

# %%
output_index = interpreter.get_output_details()[0]['index']
output_index

# %%
sum_correct = 0.0
for idx, (x, y) in enumerate(ds_valid):
    img = (x+1.0)/2.0*255.0
    #image = tf.expand_dims(img, axis=0)
    img = tf.cast(img, tf.uint8)
    #print(image)
    #break
    interpreter.set_tensor(input_index, img)
    interpreter.invoke()
    pred = interpreter.get_tensor(output_index)
    if np.argmax(pred) == np.argmax(y):
        sum_correct += 1.0
    
    #if idx == 2: break

# %%
mean_acc = sum_correct/float(idx+1)
mean_acc

# %%
img.shape

# %% [markdown]
# Prediction

# %%
# Perform inference on the validation dataset
predictions = new_model.predict(ds_valid)

# %%
predictions[0].shape

# %%
len(predictions)

# %%
predictions[0]

# %%
predictions[1]

# %%
atel_labels = (np.argmax(predictions[0], axis=1)).astype(int)
atel_labels

# %%
plef_labels = (np.argmax(predictions[4], axis=1)).astype(int)
plef_labels

# %%
# 각 label==1일 확률
probs = []
for label_arr in predictions:
    label_prob = []
    for pred in label_arr:
        prob = pred[1]
        label_prob.append(prob)
    probs.append(label_prob)
predictions2 = np.empty((202,5))
for i in range(len(probs[0])):
    row = [elem[i] for elem in probs]
    predictions2[i] = row

# %%
predictions2.shape

# %%
predictions2[0]

# %%
# Get the true labels from the validation dataset
true_labels = np.array([label.numpy() for _, label in ds_valid])
true_labels = np.reshape(true_labels, (-1, NUM_CLASSES))  # Reshape to 2D array

# %%
images = transform(DATASET_DIR)

# %%
plt.imshow(images[0])

# %%
explainer = lime_image.LimeImageExplainer()
explainer_l = explainer.explain_instance(images[0], new_model.predict, hide_color=0, top_labels=2, num_samples=1000)
#explainer_l = explainer.explain_instance(images[0], interpreter.get_tensor, hide_color=0, top_labels=2, num_samples=1000)

plt.imshow(explainer_l.segments)
#plt.savefig('lime.png')

# %%
temp, mask = explainer.get_image_and_mask(240, positive_only=True, num_features=5, hide_rest=True)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))

# %%
#generate_prediction_sample(exp, exp.top_labels[0], show_positive = True, hide_background = True)
generate_prediction_sample(explainer_l, explainer_l.top_labels[1], show_positive = False, hide_background = False)

# %%
# Initialize a list to store dataset elements
elements = []

# Iterate over the dataset and collect elements
for element in ds_valid:
    resized_image = tf.image.resize(element[0].numpy(), IMAGE_SIZE)
    print(element[1])
    elements.append(resized_image.numpy())

# Convert the elements list to a NumPy array
elements = np.array(elements)
# Reshape the elements array
X = np.squeeze(elements, axis=1)

# %%
elements.shape

# %%
label = []
for i in ds_valid:
    label.append(i[1].numpy())

# %%
# define a masker that is used to mask out partitions of the input image, this one uses a blurred background
masker0 = shap.maskers.Image("inpaint_telea", X[0].shape)

# %%
X[201].shape

# %%
def f(X):
    tmp = X.copy()    
    tmp = tmp / 255.0
    return new_model(tmp)[0]

# %%
def f1(X):
    tmp = X.copy()    
    tmp = tmp / 255.0
    return new_model(tmp)[1]

# %% [markdown]
# Deep explainer

# %%
# select backgroud for shap
# training set
background = images[np.random.choice(images.shape[0], 100, replace=False)]

# %%
type(background)

# %%
type(images)

# %%
type(X)

# %%
type(predictions2)

# %%
type(masker0)

# %%
# DeepExplainer to explain predictions of the model
# model (output (,1)), data (numpy.array, pd.DataFrame)
explainer_sd = shap.DeepExplainer(new_model, background[0])
# X (list - numpy.array, pd.DataFrame)
shap_values = explainer_sd(X[:10])

# %% [markdown]
# Vanilla explainer

# %%
explainer_s = shap.Explainer(f, masker0, output_names=TARGET_COLUMNS)
# compute shap values
#shap_values = explainer_s.shap_values(images[0])
shap_values = explainer_s(X[:10], max_evals = 100, batch_size=BATCH_SIZE, outputs=shap.Explanation.argsort.flip[:1])

# %%
for i in range(10):
    shap.image_plot(shap_values[i])
    print(label[i])

# %%
for i in range(10):
    shap.image_plot(shap_values[i])

# %%
for i in range(10):
    shap.image_plot(shap_values[i])

# %%
# multi-label

# %%
import h5py
import json
f = h5py.File(MODEL_DIR)
revealcancel_model = kc.convert_model_from_saved_files(
                            h5_file=MODEL_DIR,
                            nonlinear_mxts_mode=NonlinearMxtsMode.RevealCancel)

# %%
new_model.get_layers()[0]
